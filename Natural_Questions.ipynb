# %%
# %load_ext autoreload

# %%
import os
os.path.abspath(os.curdir)
# Out:
# '/Users/md/Downloads/qa'

# %%
# %autoreload 2
from src.natural_questions import NaturalQuestions
from src.utils import flatten_list, read_data

# %%
import pandas as pd

# %%
df_qa=read_data(file_name='data/simplified-nq-train.jsonl', length=10000)

# %%
17*1000/55
# Out:
# 309.09090909090907

# %%
# %%time
nq=NaturalQuestions(df_qa)
# Out:
# CPU times: user 9.9 s, sys: 69.8 ms, total: 9.97 s
# Wall time: 9.98 s

# %%
# %%time
nq.get_entities()
# Out:
# CPU times: user 18.3 s, sys: 33.3 ms, total: 18.3 s
# Wall time: 18.3 s

# %%
nq.summary()
# Out:
# Average number of annotations 1.0
# Short answers 4372, 43.72%
# Multiple short answers 1175, 12.0%
# Long answers 10000, 100.0%
# % bool answers 0.0122

# %%
(nq.df_qa.ANS_LONG=='').sum()
# Out:
# 5000

# %%
value_counts_top(nq.df_qa[nq.df_qa.HAS_SHORT]['first'],top_n=9).plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='first'>

# %%
value_counts_top(nq.df_qa[nq.df_qa.HAS_SHORT==False]['first'],top_n=9).plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='first'>

# %%
nq.df_qa['ENTITY']=nq.df_qa.ENTS_SHORT.apply(lambda ents: ' '.join(set([e['label'] for e in ents])))#.value_counts().head(20)

# %%
value_counts_top(nq.df_qa[nq.df_qa['HAS_SHORT']]['ENTITY'],top_n=9).plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='ENTITY'>

# %%
value_counts_top(nq.df_qa[nq.df_qa['ENTITY']=='GPE']['first'],top_n=9).plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='first'>

# %%
value_counts_top(nq.df_qa[nq.df_qa['ENTITY']=='PERSON']['first'],top_n=9).plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='first'>

# %%
value_counts_top(nq.df_qa[nq.df_qa['ENTITY']=='GPE']['first'],top_n=9).plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='first'>

# %%
(nq.df_qa.ANS_LONG=='').astype(int).plot()
# Out:
# <AxesSubplot:>

# %%
nq.df_qa.head(3)
# Out:
#                                        document_text  \
# 0  Email marketing - Wikipedia <H1> Email marketi...
# 1  The Mother ( How I Met Your Mother ) - wikiped...
# 2  Human fertilization - wikipedia <H1> Human fer...
#
#                               long_answer_candidates  \
# 0  [{'start_token': 14, 'top_level': True, 'end_t...
# 1  [{'start_token': 28, 'top_level': True, 'end_t...
# 2  [{'start_token': 14, 'top_level': True, 'end_t...
#
#                                        question_text  \
# 0  which is the most common use of opt-in e-mail ...
# 1            how i.met your mother who is the mother
# 2   what type of fertilisation takes place in humans
#
#                                          annotations  \
# 0  [{'yes_no_answer': 'NONE', 'long_answer': {'st...
# 1  [{'yes_no_answer': 'NONE', 'long_answer': {'st...
# 2  [{'yes_no_answer': 'NONE', 'long_answer': {'st...
#
#                                         document_url           example_id  \
# ...

# %%
''.join({'1,','3','2'})
# Out:
# '231,'

# %%
is_short_answer=nq.df_qa.ANS_SHORT.apply(lambda x: len(x)>0)
nq.df_qa[is_short_answer].ENTS_SHORT.apply(lambda ents: len(set([e['label'] for e in ents]))).value_counts()
# Out:
# 1    2352
# 0     826
# 2     294
# 3      63
# 4      24
# 5       4
# 6       3
# Name: ENTS_SHORT, dtype: int64

# %%
nq.df_qa[nq.df_qa.ENTS_SHORT.apply(lambda x: len(x)>3)]
# Out:
#                                           document_text  \
# 30    Powerball - wikipedia <H1> Powerball </H1> Jum...
# 45    List of Olympic Games host cities - wikipedia ...
# 194   Bataan Death March - wikipedia <H1> Bataan Dea...
# 243   Fort Myers , Florida - wikipedia <H1> Fort Mye...
# 246   2018 Winter Olympics opening ceremony - wikipe...
# ...                                                 ...
# 9642  Volcán de Colima - wikipedia <H1> Volcán de Co...
# 9688  I Want You Back - wikipedia <H1> I Want You Ba...
# 9698  Lagos State ministry of Education - Wikipedia ...
# 9714  2018 FIFA World Cup knockout stage - wikipedia...
# 9974  That 's So Raven ( soundtrack ) - wikipedia <H...
#
#                                  long_answer_candidates  \
# 30    [{'start_token': 43, 'top_level': True, 'end_t...
# 45    [{'start_token': 22, 'top_level': True, 'end_t...
# 194   [{'start_token': 10, 'top_level': True, 'end_t...
# 243   [{'start_token': 24, 'top_level': True, 'end_t...
# ...

# %%
srs=pd.Series(flatten_list(
    nq.df_qa.ENTS_SHORT.apply(lambda ents: 
                              list(set([e['label'] for e in ents]))))).value_counts()

# %%
srs.plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='None'>

# %%
nq.df_qa.ANS_SHORT.apply(lambda x: len(x)>0).value_counts().plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='ANS_SHORT'>

# %%
nq.df_qa.ANS_SHORT.apply(lambda x: ''.join(x)).value_counts().head(20)
# Out:
#            6434
# 2018         12
# 2016          8
# five          7
# 10            7
# 2002          6
# 2008          6
# 18            5
# 1988          5
# 1985          5
# 2019          5
# 1990          5
# 8             5
# 2017          5
# four          5
# three         5
# England       4
# 1980          4
# 1993          4
# 1986          4
# Name: ANS_SHORT, dtype: int64

# %%
nq.df_qa[nq.df_qa.ANS_YES_NO!='NONE']['first'].shape#value_counts()
# Out:
# (122,)

# %%
nq.df_qa.ENTS_SHORT.apply(lambda ents: [e['label'] for e in ents])

# %%
pd.Series(flatten_list(nq.df_qa.ENTS_SHORT.apply(lambda ents: [e['label'] for e in ents]))).value_counts().sum()
# Out:
# 4197

# %%
df_qa.question_text.apply(lambda x: x.split()[0]).value_counts().head(10).plot.pie(figsize=(6, 6),autopct='%.2f',)
# Out:
# <AxesSubplot:ylabel='question_text'>

# %%
df_qa[['first','second','document_url']].groupby(['first','second']).count()\
    .sort_values('document_url',ascending=False)\
    .head(50)
# Out:
#                      document_url
# first      second
# what       is                 620
# when       did                472
# who        is                 372
# how        many               358
# when       was                285
#            does               261
# where      is                 260
# who        plays              240
#            played             236
# where      did                234
#            does               225
# who        was                204
#            has                138
#            sang               135
#            sings              131
#            won                131
#            wrote              118
# what       are                116
# where      was                113
# what       was                110
# when       is                 107
# which      of                  99
# what       does                89
# when       do                  84
# who        did                 82
# where      do                  80
# ...

# %%
df_qa[df_qa['first'].isin(['i','a'])].head(50)
# Out:
#                                           document_text  \
# 13    I Had trouble in Getting to Solla Sollew - wik...
# 24    I Love It ( Icona Pop song ) - wikipedia <H1> ...
# 63    I Am a Fugitive from a Georgia Chain Gang ! - ...
# 116   Dressing ( medical ) - wikipedia <H1> Dressing...
# 119   Rivers of Blood speech - wikipedia <H1> Rivers...
# 353   Dependent and independent variables - wikipedi...
# 477   In Bloom - wikipedia <H1> In Bloom </H1> For t...
# 690   Bang the Drum all day - wikipedia <H1> Bang th...
# 766   Arya Samaj - Wikipedia <H1> Arya Samaj </H1> J...
# 790   A Cinderella Story : Once Upon a song - Wikipe...
# 912   A Great Day in Harlem ( photograph ) - wikiped...
# 978   Rift valley - wikipedia <H1> Rift valley </H1>...
# 1100  I Ca n't get You Off of My Mind - wikipedia <H...
# 1122  Drink You Away - wikipedia <H1> Drink You Away...
# 1171  The farmer and the viper - wikipedia <H1> The ...
# 1429  A fair to Remember ( Modern Family ) - wikiped...
# ...

# %%
df_qa.loc[0]
# Out:
# document_text             Email marketing - Wikipedia <H1> Email marketi...
# long_answer_candidates    [{'start_token': 14, 'top_level': True, 'end_t...
# question_text             which is the most common use of opt-in e-mail ...
# annotations               [{'yes_no_answer': 'NONE', 'long_answer': {'st...
# document_url              https://en.wikipedia.org//w/index.php?title=Em...
# example_id                                              5655493461695504401
# first                                                                 which
# second                                                                   is
# Name: 0, dtype: object

# %%
df_qa.loc[0]['question_text']
# Out:
# 'which is the most common use of opt-in e-mail marketing'

# %%
df_qa.loc[0]['annotations'][0]
# Out:
# {'yes_no_answer': 'NONE',
#  'long_answer': {'start_token': 1952,
#   'candidate_index': 54,
#   'end_token': 2019},
#  'short_answers': [{'start_token': 1960, 'end_token': 1969}],
#  'annotation_id': 593165450220027640}

# %%
pd.set_option('display.max_colwidth', 150)

# %%
df_qa[df_qa.YES_NO!='NONE'].head(50)
# Out:
#                                                                                                                                               document_text  \
# 61    Commonwealth of Nations - wikipedia <H1> Commonwealth of Nations </H1> Jump to : navigation , search `` The Commonwealth '' redirects here . It is...
# 96    Public holidays in Spain - wikipedia <H1> Public holidays in Spain </H1> Jump to : navigation , search <P> If one of the `` national holidays '' h...
# 113   Micrometer - wikipedia <H1> Micrometer </H1> Jump to : navigation , search This article is about the measuring device . For the unit of length , s...
# 326   History of the Philadelphia Eagles - wikipedia <H1> History of the Philadelphia Eagles </H1> Jump to : navigation , search <Table> <Tr> <Td> </Td>...
# 359   The Chase ( US Game Show ) - Wikipedia <H1> The Chase ( US Game Show ) </H1> <P> </P> <Table> <Tr> <Th_colspan="2"> The Chase </Th> </Tr> <Tr> <Td...
# ...

# %%
df_qa.loc[0]['document_text'].split()[1960:1969]
# Out:
# ['a',
#  'newsletter',
#  'sent',
#  'to',
#  'an',
#  'advertising',
#  'firm',
#  "'s",
#  'customers']

# %%
df_qa.loc[0]['document_text']
# Out:
# "Email marketing - Wikipedia <H1> Email marketing </H1> Jump to : navigation , search <Table> <Tr> <Td> </Td> <Td> ( hide ) This article has multiple issues . Please help improve it or discuss these issues on the talk page . ( Learn how and when to remove these template messages ) <Table> <Tr> <Td> </Td> <Td> This article needs additional citations for verification . Please help improve this article by adding citations to reliable sources . Unsourced material may be challenged and removed . ( September 2014 ) ( Learn how and when to remove this template message ) </Td> </Tr> </Table> <Table> <Tr> <Td> </Td> <Td> This article possibly contains original research . Please improve it by verifying the claims made and adding inline citations . Statements consisting only of original research should be removed . ( January 2015 ) ( Learn how and when to remove this template message ) </Td> </Tr> </Table> ( Learn how and when to remove this template message ) </Td> </Tr> </Table> <Table> <Tr> 
# ...

# %%
pd.Series(df_qa.loc[0]['document_text'].split()).value_counts().head(50)
# Out:
# <Li>           161
# </Li>          161
# .              144
# ,              135
# to              80
# the             78
# of              69
# and             65
# email           57
# marketing       52
# a               44
# )               37
# (               37
# or              29
# -               28
# in              28
# </Ul>           27
# ''              27
# ``              27
# </P>            27
# <P>             27
# <Ul>            27
# is              25
# emails          23
# Jump            23
# up              23
# with            22
# ^               22
# Email           22
# for             21
# on              20
# </H3>           19
# <H3>            19
# advertising     17
# as              17
# that            17
# :               16
# The             16
# be              15
# <Tr>            14
# </Tr>           14
# their           12
# %               12
# Retrieved       12
# </Td>           12
# messages        12
# from            12
# ...

# %%
df_qa.loc[0]['annotations'][0]
# Out:
# {'yes_no_answer': 'NONE',
#  'long_answer': {'start_token': 1952,
#   'candidate_index': 54,
#   'end_token': 2019},
#  'short_answers': [{'start_token': 1960, 'end_token': 1969}],
#  'annotation_id': 593165450220027640}

# %%
25+15+13+10+6+1
# Out:
# 70

# %%
df_qa.question_text.apply(lambda x: ' '.join(x.split()[:1])).value_counts().head(50)
# Out:
# who           2502
# what          1492
# when          1280
# where         1010
# how            627
# the            352
# which          275
# why            135
# is             103
# in              62
# a               62
# list            61
# what's          45
# who's           34
# i               31
# do              27
# does            24
# name            24
# all             22
# can             22
# difference      22
# describe        21
# are             20
# cast            20
# most            16
# explain         16
# did             14
# an              14
# write           14
# top             13
# last            12
# two             12
# first           11
# you             11
# one             11
# meaning         10
# star            10
# new             10
# at               9
# was              8
# summary          8
# give             8
# names            8
# actor            8
# to               8
# discuss          8
# my               8
# ...

# %%
df_qa.loc[0]['document_url']
# Out:
# 'https://en.wikipedia.org//w/index.php?title=Email_marketing&amp;oldid=814071202'

# %%
df_qa.question_text.apply(lambda x: ' '.join(x.split()[:2])).value_counts().head(50)
# Out:
# what is               620
# when did              472
# who is                372
# how many              358
# when was              285
# when does             261
# where is              260
# who plays             240
# who played            236
# where did             234
# where does            225
# who was               204
# who has               138
# who sang              135
# who won               131
# who sings             131
# who wrote             118
# what are              116
# where was             113
# what was              110
# when is               107
# which of               99
# what does              89
# when do                84
# who did                82
# where do               80
# who does               65
# who are                64
# where are              54
# list of                53
# what kind              43
# how did                41
# what's the             40
# what happened          38
# why did                38
# ...

# %%
import json

json.loads(single_line).keys()
# Out:
# dict_keys(['document_text', 'long_answer_candidates', 'question_text', 'annotations', 'document_url', 'example_id'])

# %%
json.loads(single_line)['question_text']
# Out:
# 'which is the most common use of opt-in e-mail marketing'

# %%
json.loads(single_line)['annotations']
# Out:
# [{'yes_no_answer': 'NONE',
#   'long_answer': {'start_token': 1952,
#    'candidate_index': 54,
#    'end_token': 2019},
#   'short_answers': [{'start_token': 1960, 'end_token': 1969}],
#   'annotation_id': 593165450220027640}]
